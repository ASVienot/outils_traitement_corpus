# %%
import pandas as pd 

data = pd.read_csv("recettes.csv")
data

#na filter
# Out:
#       id                                              liens  \
# 0      1  https://quandnadcuisine.fr/salade-de-quinoa-a-...
# 1      2  https://quandnadcuisine.fr/bricks-au-thon-et-t...
# 2      3  https://quandnadcuisine.fr/ballotins-au-chevre...
# 3      4  https://quandnadcuisine.fr/clafoutis-petits-po...
# 4      5  https://quandnadcuisine.fr/clafoutis-poireaux-...
# ..   ...                                                ...
# 445  446  https://www.elle.fr/Elle-a-Table/Recettes-de-c...
# 446  447  https://www.elle.fr/Elle-a-Table/Recettes-de-c...
# 447  448  https://www.elle.fr/Elle-a-Table/Recettes-de-c...
# 448  449  https://www.elle.fr/Elle-a-Table/Recettes-de-c...
# 449  450  https://www.elle.fr/Elle-a-Table/Recettes-de-c...
#
#                                                 textes  vegetarien  vegan  \
# 0    Let’s go en cuisine pour préparer cette salade...           1      1
# 1    Let’s go en cuisine pour préparer ces bricks a...           0      0
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("csv", data_files="./recettes.csv", split="train")
dataset
#dataset[2] # ligne 2
# Out:
# Found cached dataset csv (/home/tacitus/.cache/huggingface/datasets/csv/default-b306e72bfaae34db/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
# Dataset({
#     features: ['id', 'liens', 'textes', 'vegetarien', 'vegan', 'crudivore', 'sans_gluten', 'alixproof', 'sans_noix', 'sucré/salé', 'Commentaires', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#     num_rows: 450
# })
